# %% [markdown]
# # Ambiente

# %%
# https://github.com/mljar/mljar-supervised
# !pip install -q -U mljar-supervised
# !pip install -q -U matplotlib==3.1.3 
from supervised.automl import AutoML
from supervised.preprocessing.eda import EDA
from sklearn.model_selection import train_test_split

import pandas as pd
from datetime import datetime
# Out:
#      |████████████████████████████████| 113 kB 8.7 MB/s
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
#      |████████████████████████████████| 192.9 MB 47 kB/s
#      |████████████████████████████████| 2.0 MB 48.2 MB/s
#      |████████████████████████████████| 76.6 MB 1.2 MB/s
#      |████████████████████████████████| 61 kB 233 kB/s
#      |████████████████████████████████| 319 kB 65.6 MB/s
#      |████████████████████████████████| 366 kB 58.9 MB/s
#      |████████████████████████████████| 86 kB 5.4 MB/s
#      |████████████████████████████████| 308 kB 74.3 MB/s
#      |████████████████████████████████| 81 kB 7.6 MB/s
#      |████████████████████████████████| 210 kB 72.9 MB/s
#      |████████████████████████████████| 78 kB 5.0 MB/s
#      |████████████████████████████████| 146 kB 49.9 MB/s
#      |████████████████████████████████| 112 kB 50.9 MB/s
#      |████████████████████████████████| 49 kB 4.8 MB/s
#   Building wheel for mljar-supervised (setup.py) ... done
#   Building wheel for shap (setup.py) ... done
#   Building wheel for dtreeviz (setup.py) ... done
#   Building wheel for pyperclip (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
#      |████████████████████████████████| 13.1 MB 9.8 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mljar-supervised 0.11.2 requires matplotlib>=3.2.2, but you have matplotlib 3.1.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %% [markdown]
# # MLJar

# %%
tempo_processamento_sec = 60*60
seed = 123

# %%
def train_mljar(label, table, seed):
    X_train, X_test, y_train, y_test = train_test_split(table.drop(label, axis=1),
                                                        table[label],
                                                        test_size=0.30,
                                                        random_state=seed)

    automl = AutoML(total_time_limit=tempo_processamento_sec,
                    mode="Compete",
                    eval_metric="auc",
                    ml_task="binary_classification",
                    train_ensemble=False,
                    stack_models=False,
                    random_state = seed,
                    algorithms = ['Random Forest', 'Xgboost', 'Decision Tree', 'Baseline', 'LightGBM', 'Extra Trees', 'CatBoost', 'Linear', 'Nearest Neighbors'] )
    automl.fit(X_train,y_train)
    return automl.report()

# %% [markdown]
# ## Adult.csv

# %%
dataset = "adult"
url = '/content/drive/MyDrive/Luiz Gabriel - PC/13.Pós Data Science UFPR/00.TCC/Especializacao_Data_Science_Big_Data_Monografia/data/adult.csv'
df = pd.read_csv(url, sep=',')
label = "class"

# %%
start_time = datetime.now()

metrics = train_mljar(label="class", table=df, seed=seed)

end_time = datetime.now()
execution_time = end_time - start_time

metrics
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
print('Duration {} : {}'.format(dataset, end_time - start_time))
# Out:
# Duration adult : 0:59:41.994081

# %% [markdown]
# ## kc1.csv

# %%
dataset = "kc1"
label = "defects"
url = '/content/drive/MyDrive/Luiz Gabriel - PC/13.Pós Data Science UFPR/00.TCC/Especializacao_Data_Science_Big_Data_Monografia/data/kc1.csv'
df = pd.read_csv(url, sep=',')

# %%
start_time = datetime.now()

metrics = train_mljar(label=label, table=df, seed=seed)

end_time = datetime.now()
execution_time = end_time - start_time

metrics
# Out:
# AutoML directory: AutoML_2
# The task is binary_classification with evaluation metric auc
# AutoML will use algorithms: ['Random Forest', 'Xgboost', 'Decision Tree', 'Baseline', 'LightGBM', 'Extra Trees', 'CatBoost', 'Linear', 'Nearest Neighbors']
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree auc 0.830783 trained in 7.63 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 5-fold CV Shuffle,Stratify
# * Step simple_algorithms will try to check up to 5 models
# 1_Baseline auc 0.49823 trained in 1.4 seconds
# 2_DecisionTree auc 0.753382 trained in 2.07 seconds
# 3_DecisionTree auc 0.746894 trained in 2.28 seconds
# 4_DecisionTree auc 0.76069 trained in 2.08 seconds
# 5_Linear auc 0.77706 trained in 4.61 seconds
# * Step default_algorithms will try to check up to 6 models
# 6_Default_LightGBM auc 0.768625 trained in 3.56 seconds
# 7_Default_Xgboost auc 0.769763 trained in 11.53 seconds
# 8_Default_CatBoost auc 0.803749 trained in 4.86 seconds
# 9_Default_RandomForest auc 0.789779 trained in 12.17 seconds
# 10_Default_ExtraTrees auc 0.793227 trained in 9.08 seconds
# 11_Default_NearestNeighbors auc 0.703926 trained in 4.57 seconds
# * Step not_so_random will try to check up to 52 models
# 21_LightGBM auc 0.786712 trained in 3.33 seconds
# 12_Xgboost auc 0.76015 trained in 10.14 seconds
# 30_CatBoost auc 0.779103 trained in 7.91 seconds
# 39_RandomForest auc 0.801671 trained in 10.81 seconds
# 48_ExtraTrees auc 0.795465 trained in 11.04 seconds
# 57_NearestNeighbors auc 0.686437 trained in 5.1 seconds
# 22_LightGBM auc 0.786763 trained in 4.82 seconds
# 13_Xgboost auc 0.778046 trained in 13.44 seconds
# 31_CatBoost auc 0.805177 trained in 5.96 seconds
# 40_RandomForest auc 0.786795 trained in 9.65 seconds
# 49_ExtraTrees auc 0.7848 trained in 9.62 seconds
# 58_NearestNeighbors auc 0.686437 trained in 6.46 seconds
# 23_LightGBM auc 0.767147 trained in 6.54 seconds
# 14_Xgboost auc 0.636549 trained in 11.46 seconds
# 32_CatBoost auc 0.774575 trained in 18.51 seconds
# 41_RandomForest auc 0.792474 trained in 11.9 seconds
# 50_ExtraTrees auc 0.786565 trained in 11.76 seconds
# 59_NearestNeighbors auc 0.738113 trained in 7.26 seconds
# 24_LightGBM auc 0.776179 trained in 6.06 seconds
# 15_Xgboost auc 0.771674 trained in 13.35 seconds
# 33_CatBoost auc 0.800906 trained in 7.51 seconds
# 42_RandomForest auc 0.804421 trained in 10.31 seconds
# 51_ExtraTrees auc 0.799223 trained in 10.87 seconds
# 60_NearestNeighbors auc 0.682687 trained in 6.87 seconds
# 25_LightGBM auc 0.775804 trained in 6.94 seconds
# 16_Xgboost auc 0.728842 trained in 12.87 seconds
# 34_CatBoost auc 0.795768 trained in 9.46 seconds
# 43_RandomForest auc 0.805444 trained in 12.93 seconds
# 52_ExtraTrees auc 0.802099 trained in 11.79 seconds
# 61_NearestNeighbors auc 0.718497 trained in 8.31 seconds
# 26_LightGBM auc 0.76063 trained in 6.93 seconds
# 17_Xgboost auc 0.780621 trained in 17.12 seconds
# 35_CatBoost auc 0.794257 trained in 11.29 seconds
# 44_RandomForest auc 0.788922 trained in 14.09 seconds
# 53_ExtraTrees auc 0.790239 trained in 11.58 seconds
# 62_NearestNeighbors auc 0.682687 trained in 9.21 seconds
# 27_LightGBM auc 0.795276 trained in 7.74 seconds
# 18_Xgboost auc 0.737747 trained in 17.23 seconds
# 36_CatBoost auc 0.727878 trained in 16.53 seconds
# 45_RandomForest auc 0.794255 trained in 15.15 seconds
# 54_ExtraTrees auc 0.793819 trained in 15.49 seconds
# 63_NearestNeighbors auc 0.719258 trained in 8.96 seconds
# 28_LightGBM auc 0.787368 trained in 8.93 seconds
# 19_Xgboost auc 0.730412 trained in 24.33 seconds
# 37_CatBoost auc 0.793324 trained in 10.13 seconds
# 46_RandomForest auc 0.811844 trained in 15.16 seconds
# 55_ExtraTrees auc 0.801133 trained in 17.41 seconds
# 29_LightGBM auc 0.781595 trained in 10.92 seconds
# 20_Xgboost auc 0.706573 trained in 21.1 seconds
# 38_CatBoost auc 0.764703 trained in 11.4 seconds
# 47_RandomForest auc 0.794196 trained in 16.18 seconds
# 56_ExtraTrees auc 0.801533 trained in 14.39 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: l_ratio_ev_g
# Add Golden Feature: i_ratio_uniq_Opnd
# Add Golden Feature: b_ratio_t
# Add Golden Feature: b_ratio_e
# Add Golden Feature: l_ratio_uniq_Op
# Add Golden Feature: total_Op_ratio_e
# Add Golden Feature: l_ratio_b
# Add Golden Feature: i_ratio_b
# Add Golden Feature: total_Op_ratio_b
# Add Golden Feature: l_ratio_d
# Created 10 Golden Features in 11.43 seconds.
# 46_RandomForest_GoldenFeatures auc 0.821021 trained in 29.47 seconds
# 43_RandomForest_GoldenFeatures auc 0.80723 trained in 18.07 seconds
# 31_CatBoost_GoldenFeatures auc 0.801138 trained in 12.37 seconds
# * Step kmeans_features will try to check up to 3 models
# 46_RandomForest_KMeansFeatures auc 0.798218 trained in 25.73 seconds
# 43_RandomForest_KMeansFeatures auc 0.802593 trained in 20.88 seconds
# 31_CatBoost_KMeansFeatures auc 0.785602 trained in 16.42 seconds
# * Step insert_random_feature will try to check up to 1 model
# 46_RandomForest_GoldenFeatures_RandomFeature auc 0.811039 trained in 60.22 seconds
# Drop features ['e', 't', 'random_feature', 'locCodeAndComment', 'i_ratio_b', 'v_g', 'l_ratio_uniq_Op', 'b_ratio_t', 'total_Op_ratio_e', 'ev_g', 'l_ratio_d']
# * Step features_selection will try to check up to 5 models
# 46_RandomForest_GoldenFeatures_SelectedFeatures auc 0.812579 trained in 17.39 seconds
# 31_CatBoost_SelectedFeatures auc 0.793071 trained in 11.02 seconds
# 52_ExtraTrees_SelectedFeatures auc 0.794993 trained in 13.72 seconds
# 27_LightGBM_SelectedFeatures auc 0.802708 trained in 11.89 seconds
# 17_Xgboost_SelectedFeatures auc 0.790834 trained in 19.33 seconds
# * Step hill_climbing_1 will try to check up to 25 models
# 64_RandomForest_GoldenFeatures auc 0.810117 trained in 17.35 seconds
# 65_RandomForest_GoldenFeatures auc 0.815446 trained in 17.25 seconds
# 66_RandomForest_GoldenFeatures_SelectedFeatures auc 0.816373 trained in 15.99 seconds
# 67_RandomForest_GoldenFeatures_SelectedFeatures auc 0.813871 trained in 19.73 seconds
# 68_RandomForest auc 0.815653 trained in 20.55 seconds
# 69_RandomForest auc 0.809772 trained in 16.59 seconds
# 70_CatBoost auc 0.798404 trained in 14.97 seconds
# 71_CatBoost auc 0.749331 trained in 12.89 seconds
# 72_LightGBM_SelectedFeatures auc 0.785869 trained in 10.64 seconds
# 73_LightGBM_SelectedFeatures auc 0.79691 trained in 12.28 seconds
# 74_ExtraTrees auc 0.799993 trained in 17.49 seconds
# 75_ExtraTrees auc 0.808816 trained in 16.76 seconds
# 76_ExtraTrees auc 0.801028 trained in 19.74 seconds
# 77_CatBoost_GoldenFeatures auc 0.794016 trained in 16.86 seconds
# 78_ExtraTrees auc 0.803685 trained in 18.08 seconds
# 79_ExtraTrees auc 0.797926 trained in 19.92 seconds
# 80_LightGBM auc 0.793642 trained in 13.26 seconds
# 81_LightGBM auc 0.785303 trained in 13.62 seconds
# 82_Xgboost_SelectedFeatures auc 0.771685 trained in 25.25 seconds
# 83_Xgboost_SelectedFeatures auc 0.796735 trained in 22.27 seconds
# 84_LightGBM auc 0.762609 trained in 13.64 seconds
# 85_Xgboost auc 0.779338 trained in 21.58 seconds
# 86_Xgboost auc 0.800676 trained in 21.54 seconds
# 87_Xgboost auc 0.751391 trained in 18.72 seconds
# 88_DecisionTree auc 0.75163 trained in 12.84 seconds
# * Step hill_climbing_2 will try to check up to 24 models
# 89_RandomForest_GoldenFeatures auc 0.811908 trained in 23.0 seconds
# 90_RandomForest_GoldenFeatures_SelectedFeatures auc 0.814251 trained in 18.59 seconds
# 91_RandomForest auc 0.798455 trained in 23.72 seconds
# 92_ExtraTrees auc 0.801949 trained in 18.62 seconds
# 93_CatBoost auc 0.795404 trained in 16.26 seconds
# 94_CatBoost auc 0.801395 trained in 16.68 seconds
# 95_CatBoost auc 0.764391 trained in 17.94 seconds
# 96_CatBoost auc 0.804099 trained in 15.32 seconds
# 97_ExtraTrees auc 0.803561 trained in 22.26 seconds
# 98_LightGBM_SelectedFeatures auc 0.78085 trained in 16.47 seconds
# 99_ExtraTrees auc 0.796869 trained in 20.58 seconds
# 100_CatBoost_GoldenFeatures auc 0.774083 trained in 19.25 seconds
# 101_CatBoost_GoldenFeatures auc 0.793126 trained in 20.54 seconds
# 102_Xgboost auc 0.774646 trained in 28.44 seconds
# 103_Xgboost auc 0.754122 trained in 23.32 seconds
# 104_LightGBM_SelectedFeatures auc 0.765135 trained in 16.48 seconds
# 105_Xgboost_SelectedFeatures auc 0.767368 trained in 24.89 seconds
# 106_Xgboost_SelectedFeatures auc 0.753874 trained in 24.31 seconds
# 107_LightGBM auc 0.787473 trained in 15.79 seconds
# 108_Xgboost_SelectedFeatures auc 0.779464 trained in 24.99 seconds
# 109_Xgboost_SelectedFeatures auc 0.781754 trained in 24.67 seconds
# 110_DecisionTree auc 0.758943 trained in 14.13 seconds
# 111_DecisionTree auc 0.758943 trained in 16.2 seconds
# 112_DecisionTree auc 0.739896 trained in 19.21 seconds
# * Step boost_on_errors will try to check up to 1 model
# 46_RandomForest_GoldenFeatures_BoostOnErrors auc 0.814163 trained in 28.12 seconds
# AutoML fit time: 2068.92 seconds
# AutoML best model: 46_RandomForest_GoldenFeatures

# %%
print('Duration {} : {}'.format(dataset, end_time - start_time))

# %% [markdown]
# ## blood_transfusion.csv

# %%
dataset = "blood_transfusion"
label = "Class"
url = '/content/drive/MyDrive/Luiz Gabriel - PC/13.Pós Data Science UFPR/00.TCC/Especializacao_Data_Science_Big_Data_Monografia/data/blood_transfusion.csv'
df = pd.read_csv(url, sep=',')

# %%
start_time = datetime.now()

metrics = train_mljar(label=label, table=df, seed=seed)

end_time = datetime.now()
execution_time = end_time - start_time

metrics
# Out:
# AutoML directory: AutoML_1
# The task is binary_classification with evaluation metric auc
# AutoML will use algorithms: ['Random Forest', 'Xgboost', 'Decision Tree', 'Baseline', 'LightGBM', 'Extra Trees', 'CatBoost', 'Linear', 'Nearest Neighbors']
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree auc 0.70935 trained in 0.6 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle,Stratify
# * Step simple_algorithms will try to check up to 5 models
# 1_Baseline auc 0.490103 trained in 2.28 seconds
# 2_DecisionTree auc 0.750209 trained in 2.61 seconds
# 3_DecisionTree auc 0.747688 trained in 2.6 seconds
# 4_DecisionTree auc 0.692488 trained in 2.69 seconds
# 5_Linear auc 0.774618 trained in 4.28 seconds
# * Step default_algorithms will try to check up to 6 models
# 6_Default_LightGBM auc 0.733804 trained in 3.68 seconds
# 7_Default_Xgboost auc 0.709824 trained in 16.12 seconds
# 8_Default_CatBoost auc 0.768194 trained in 4.56 seconds
# 9_Default_RandomForest auc 0.785468 trained in 13.65 seconds
# 10_Default_ExtraTrees auc 0.773216 trained in 12.25 seconds
# 11_Default_NearestNeighbors auc 0.717671 trained in 6.95 seconds
# * Step not_so_random will try to check up to 52 models
# 21_LightGBM auc 0.782852 trained in 5.43 seconds
# 12_Xgboost auc 0.703997 trained in 16.51 seconds
# 30_CatBoost auc 0.780896 trained in 5.57 seconds
# 39_RandomForest auc 0.78372 trained in 13.68 seconds
# 48_ExtraTrees auc 0.785666 trained in 13.7 seconds
# 57_NearestNeighbors auc 0.683679 trained in 8.38 seconds
# 22_LightGBM auc 0.772567 trained in 6.56 seconds
# 13_Xgboost auc 0.706759 trained in 19.38 seconds
# 31_CatBoost auc 0.785897 trained in 9.09 seconds
# 40_RandomForest auc 0.772494 trained in 16.56 seconds
# 49_ExtraTrees auc 0.773938 trained in 15.7 seconds
# 58_NearestNeighbors auc 0.683679 trained in 8.77 seconds
# 23_LightGBM auc 0.767922 trained in 7.36 seconds
# 14_Xgboost auc 0.704112 trained in 18.99 seconds
# 32_CatBoost auc 0.754112 trained in 9.59 seconds
# 41_RandomForest auc 0.773049 trained in 18.38 seconds
# 50_ExtraTrees auc 0.766541 trained in 19.11 seconds
# 59_NearestNeighbors auc 0.70249 trained in 11.32 seconds
# 24_LightGBM auc 0.770726 trained in 8.82 seconds
# 15_Xgboost auc 0.756277 trained in 26.0 seconds
# 33_CatBoost auc 0.793806 trained in 10.15 seconds
# 42_RandomForest auc 0.777935 trained in 18.33 seconds
# 51_ExtraTrees auc 0.775602 trained in 19.99 seconds
# 60_NearestNeighbors auc 0.689642 trained in 13.01 seconds
# 25_LightGBM auc 0.772567 trained in 9.65 seconds
# 16_Xgboost auc 0.503662 trained in 20.66 seconds
# 34_CatBoost auc 0.770831 trained in 11.47 seconds
# 43_RandomForest auc 0.778468 trained in 21.36 seconds
# 52_ExtraTrees auc 0.777202 trained in 20.04 seconds
# 61_NearestNeighbors auc 0.693942 trained in 14.01 seconds
# 26_LightGBM auc 0.720266 trained in 13.4 seconds
# 17_Xgboost auc 0.742509 trained in 23.75 seconds
# 35_CatBoost auc 0.77126 trained in 12.95 seconds
# 44_RandomForest auc 0.762011 trained in 22.98 seconds
# 53_ExtraTrees auc 0.770444 trained in 23.43 seconds
# 62_NearestNeighbors auc 0.689642 trained in 14.94 seconds
# 27_LightGBM auc 0.734202 trained in 13.53 seconds
# 18_Xgboost auc 0.723718 trained in 28.66 seconds
# 36_CatBoost auc 0.752459 trained in 16.56 seconds
# 45_RandomForest auc 0.774513 trained in 22.15 seconds
# 54_ExtraTrees auc 0.774032 trained in 21.79 seconds
# 63_NearestNeighbors auc 0.72827 trained in 17.66 seconds
# 28_LightGBM auc 0.760881 trained in 14.0 seconds
# 19_Xgboost auc 0.706393 trained in 33.14 seconds
# 37_CatBoost auc 0.739046 trained in 15.17 seconds
# 46_RandomForest auc 0.809531 trained in 22.94 seconds
# 55_ExtraTrees auc 0.773289 trained in 27.68 seconds
# 29_LightGBM auc 0.753128 trained in 17.89 seconds
# 20_Xgboost auc 0.762586 trained in 35.21 seconds
# 38_CatBoost auc 0.777882 trained in 15.99 seconds
# 47_RandomForest auc 0.791777 trained in 25.65 seconds
# 56_ExtraTrees auc 0.772494 trained in 25.69 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: V3_ratio_V2
# Add Golden Feature: V2_ratio_V3
# Add Golden Feature: V2_multiply_V1
# Add Golden Feature: V3_multiply_V1
# Add Golden Feature: V4_ratio_V1
# Add Golden Feature: V4_ratio_V3
# Add Golden Feature: V3_ratio_V4
# Add Golden Feature: V4_ratio_V2
# Add Golden Feature: V2_ratio_V4
# Add Golden Feature: V2_diff_V4
# Created 10 Golden Features in 5.84 seconds.
# 46_RandomForest_GoldenFeatures auc 0.779012 trained in 33.54 seconds
# 33_CatBoost_GoldenFeatures auc 0.779347 trained in 18.2 seconds
# 47_RandomForest_GoldenFeatures auc 0.77714 trained in 27.76 seconds
# * Step kmeans_features will try to check up to 3 models
# 46_RandomForest_KMeansFeatures auc 0.793168 trained in 29.51 seconds
# 33_CatBoost_KMeansFeatures auc 0.781377 trained in 20.0 seconds
# 47_RandomForest_KMeansFeatures auc 0.788481 trained in 28.18 seconds
# * Step insert_random_feature will try to check up to 1 model
# 46_RandomForest_RandomFeature auc 0.788251 trained in 44.23 seconds
# Drop features ['random_feature']
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 27 models
# 64_RandomForest auc 0.801632 trained in 26.66 seconds
# 65_CatBoost auc 0.765003 trained in 18.76 seconds
# 66_RandomForest auc 0.780216 trained in 29.43 seconds
# 67_RandomForest auc 0.788868 trained in 28.08 seconds
# 68_RandomForest auc 0.788732 trained in 30.27 seconds
# 69_CatBoost auc 0.754206 trained in 20.29 seconds
# 70_CatBoost auc 0.76946 trained in 23.66 seconds
# 71_ExtraTrees auc 0.791348 trained in 31.04 seconds
# 72_ExtraTrees auc 0.782528 trained in 33.8 seconds
# 73_LightGBM auc 0.782852 trained in 21.36 seconds
# 74_LightGBM auc 0.782852 trained in 24.47 seconds
# 75_CatBoost auc 0.774942 trained in 26.05 seconds
# 76_ExtraTrees auc 0.779295 trained in 34.44 seconds
# 77_ExtraTrees auc 0.774346 trained in 32.83 seconds
# 78_ExtraTrees auc 0.78643 trained in 33.11 seconds
# 79_ExtraTrees auc 0.769565 trained in 31.16 seconds
# 80_LightGBM auc 0.772567 trained in 22.59 seconds
# 81_LightGBM auc 0.772567 trained in 24.97 seconds
# 82_LightGBM auc 0.772567 trained in 25.3 seconds
# 83_Xgboost auc 0.735834 trained in 41.87 seconds
# 84_Xgboost auc 0.732298 trained in 42.48 seconds
# 85_Xgboost auc 0.75701 trained in 45.82 seconds
# 86_DecisionTree auc 0.736054 trained in 26.04 seconds
# 87_DecisionTree auc 0.729263 trained in 25.78 seconds
# 88_Xgboost auc 0.726805 trained in 40.48 seconds
# 89_Xgboost auc 0.699498 trained in 37.08 seconds
# 90_DecisionTree auc 0.736054 trained in 27.49 seconds
# * Step hill_climbing_2 will try to check up to 26 models
# 91_RandomForest auc 0.779755 trained in 36.17 seconds
# 92_RandomForest auc 0.786472 trained in 38.27 seconds
# 93_RandomForest auc 0.796077 trained in 37.77 seconds
# 94_RandomForest auc 0.790082 trained in 35.96 seconds
# 95_CatBoost auc 0.777087 trained in 28.28 seconds
# 96_CatBoost auc 0.781921 trained in 27.47 seconds
# 97_RandomForest auc 0.787979 trained in 39.99 seconds
# 98_RandomForest auc 0.779253 trained in 44.74 seconds
# 99_ExtraTrees auc 0.790626 trained in 36.21 seconds
# 100_ExtraTrees auc 0.786545 trained in 40.59 seconds
# 101_ExtraTrees auc 0.784997 trained in 40.42 seconds
# 102_ExtraTrees auc 0.776439 trained in 36.39 seconds
# 103_CatBoost auc 0.770726 trained in 31.89 seconds
# 104_ExtraTrees auc 0.780425 trained in 40.91 seconds
# 105_ExtraTrees auc 0.787937 trained in 34.65 seconds
# 106_LightGBM auc 0.772651 trained in 31.53 seconds
# 107_LightGBM auc 0.774032 trained in 29.9 seconds
# 108_LightGBM auc 0.772651 trained in 32.15 seconds
# 109_LightGBM auc 0.774032 trained in 29.22 seconds
# 110_LightGBM auc 0.772651 trained in 33.05 seconds
# 111_LightGBM auc 0.774032 trained in 29.17 seconds
# 112_CatBoost auc 0.786786 trained in 30.08 seconds
# 113_CatBoost auc 0.779661 trained in 34.11 seconds
# 114_Xgboost auc 0.746443 trained in 47.36 seconds
# 115_Xgboost auc 0.75701 trained in 46.53 seconds
# 116_Xgboost auc 0.756277 trained in 47.69 seconds
# * Step boost_on_errors will try to check up to 1 model
# 46_RandomForest_BoostOnErrors auc 0.803704 trained in 40.94 seconds
# AutoML fit time: 3177.12 seconds
# AutoML best model: 46_RandomForest

# %%
print('Duration {} : {}'.format(dataset, end_time - start_time))

# %% [markdown]
# ## nomao

# %%
dataset = "nomao"
label = "Class"
url = '/content/drive/MyDrive/Luiz Gabriel - PC/13.Pós Data Science UFPR/00.TCC/Especializacao_Data_Science_Big_Data_Monografia/data/nomao.csv'
df = pd.read_csv(url, sep=',')

# %%
start_time = datetime.now()

metrics = train_mljar(label=label, table=df, seed=seed)

end_time = datetime.now()
execution_time = end_time - start_time

metrics

# %%
print('Duration {} : {}'.format(dataset, end_time - start_time))
# Out:
# Duration nomao : 0:59:56.940256

# %% [markdown]
# ## kdd

# %%
dataset = "kdd"
label = "APPETENCY"
url = '/content/drive/MyDrive/Luiz Gabriel - PC/13.Pós Data Science UFPR/00.TCC/Especializacao_Data_Science_Big_Data_Monografia/data/kdd.csv'
df = pd.read_csv(url, sep=',')

# %%
start_time = datetime.now()

metrics = train_mljar(label=label, table=df, seed=seed)

end_time = datetime.now()
execution_time = end_time - start_time

metrics

# %%
print('Duration {} : {}'.format(dataset, end_time - start_time))
# Out:
# Duration kdd : 1:00:30.001347

# %% [markdown]
# ## bank_marketing

# %%
dataset = "bank_marketing"
label = "Class"
url = '/content/drive/MyDrive/Luiz Gabriel - PC/13.Pós Data Science UFPR/00.TCC/Especializacao_Data_Science_Big_Data_Monografia/data/bank_marketing.csv'
df = pd.read_csv(url, sep=',')

# %%
start_time = datetime.now()

metrics = train_mljar(label=label, table=df, seed=seed)

end_time = datetime.now()
execution_time = end_time - start_time

metrics

# %%
print('Duration {} : {}'.format(dataset, end_time - start_time))
# Out:
# Duration bank_marketing : 1:02:48.531309

# %% [markdown]
# ## amazon_emp

# %%
dataset = "amazon_emp"
label = "target"
url = '/content/drive/MyDrive/Luiz Gabriel - PC/13.Pós Data Science UFPR/00.TCC/Especializacao_Data_Science_Big_Data_Monografia/data/amazon_emp.csv'
df = pd.read_csv(url, sep=',')

# %%
start_time = datetime.now()

metrics = train_mljar(label=label, table=df, seed=seed)

end_time = datetime.now()
execution_time = end_time - start_time

metrics

# %%
print('Duration {} : {}'.format(dataset, end_time - start_time))

# %% [markdown]
# ## jasmine

# %%
dataset = "jasmine"
label = "class"
url = '/content/drive/MyDrive/Luiz Gabriel - PC/13.Pós Data Science UFPR/00.TCC/Especializacao_Data_Science_Big_Data_Monografia/data/jasmine.csv'
df = pd.read_csv(url, sep=',')

# %%
start_time = datetime.now()

metrics = train_mljar(label=label, table=df, seed=seed)

end_time = datetime.now()
execution_time = end_time - start_time

metrics

# %%
print('Duration {} : {}'.format(dataset, end_time - start_time))

# %% [markdown]
# ## kr_vs_kp

# %%
dataset = "kr_vs_kp"
label = "class"
url = '/content/drive/MyDrive/Luiz Gabriel - PC/13.Pós Data Science UFPR/00.TCC/Especializacao_Data_Science_Big_Data_Monografia/data/kr_vs_kp.csv'
df = pd.read_csv(url, sep=',')

# %%
start_time = datetime.now()

metrics = train_mljar(label=label, table=df, seed=seed)

end_time = datetime.now()
execution_time = end_time - start_time

metrics

# %%
print('Duration {} : {}'.format(dataset, end_time - start_time))

# %% [markdown]
# ## higgs

# %%
dataset = "higgs"
label = "class"
url = '/content/drive/MyDrive/Luiz Gabriel - PC/13.Pós Data Science UFPR/00.TCC/Especializacao_Data_Science_Big_Data_Monografia/data/higgs.csv'
df = pd.read_csv(url, sep=',', low_memory=False)
df.head()

# %%
start_time = datetime.now()

metrics = train_mljar(label=label, table=df, seed=seed)

end_time = datetime.now()
execution_time = end_time - start_time

metrics

# %%
print('Duration {} : {}'.format(dataset, end_time - start_time))
